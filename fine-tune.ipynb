# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
! pip install datasets==1.18.2 transformers accelerate
# Out:
# Collecting datasets==1.18.2
#   Downloading datasets-1.18.2-py3-none-any.whl.metadata (22 kB)
# Collecting transformers
#   Downloading transformers-4.45.2-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.6 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-1.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (1.26.4)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (17.0.0)
# Requirement already satisfied: dill in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (0.3.8)
# Requirement already satisfied: pandas in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (4.66.5)
# Requirement already satisfied: xxhash in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (3.5.0)
# Requirement already satisfied: multiprocess in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from fsspec[http]>=2021.05.0->datasets==1.18.2) (2023.10.0)
# Requirement already satisfied: aiohttp in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (3.10.9)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (0.25.1)
# Requirement already satisfied: packaging in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from datasets==1.18.2) (23.2)
# Requirement already satisfied: filelock in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2024.9.11-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.4.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers)
#   Downloading tokenizers-0.20.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: psutil in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from accelerate) (2.2.0.post100)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp->datasets==1.18.2) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp->datasets==1.18.2) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp->datasets==1.18.2) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp->datasets==1.18.2) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp->datasets==1.18.2) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp->datasets==1.18.2) (1.14.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from aiohttp->datasets==1.18.2) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets==1.18.2) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.19.0->datasets==1.18.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.19.0->datasets==1.18.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.19.0->datasets==1.18.2) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from requests>=2.19.0->datasets==1.18.2) (2024.2.2)
# Requirement already satisfied: sympy in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas->datasets==1.18.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas->datasets==1.18.2) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from pandas->datasets==1.18.2) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets==1.18.2) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets==1.18.2) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/yingsun/anaconda3/envs/py310/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading datasets-1.18.2-py3-none-any.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.0/312.0 kB 8.0 MB/s eta 0:00:00:00:01
# Downloading transformers-4.45.2-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 16.0 MB/s eta 0:00:0000:0100:01
# Downloading accelerate-1.0.1-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.9/330.9 kB 7.7 MB/s eta 0:00:00:00:01
# Using cached regex-2024.9.11-cp310-cp310-macosx_11_0_arm64.whl (284 kB)
# Using cached safetensors-0.4.5-cp310-cp310-macosx_11_0_arm64.whl (381 kB)
# Downloading tokenizers-0.20.1-cp310-cp310-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 15.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: safetensors, regex, tokenizers, accelerate, transformers, datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.0.1
#     Uninstalling datasets-3.0.1:
#       Successfully uninstalled datasets-3.0.1
# Successfully installed accelerate-1.0.1 datasets-1.18.2 regex-2024.9.11 safetensors-0.4.5 tokenizers-0.20.1 transformers-4.45.2

# %%
import transformers

print(transformers.__version__)
# Out:
# 4.45.2

# %%
# Importing the libraries needed
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import seaborn as sns
import transformers
import json
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaModel, RobertaTokenizer
import logging
logging.basicConfig(level=logging.ERROR)

# %%
# Setting up the device for GPU usage

from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
df = pd.read_csv('./data/processed_data_student_stars+comments+difficult.csv')
df = df[['student_difficult', 'comments']]
df
# Out:
#        student_difficult                                           comments
# 0                    3.0  class hard twoinon gene knockout content stimu...
# 1                    2.0  definit go choos prof looney class interest cl...
# 2                    3.0  overal enjoy class assign straightforward inte...
# 3                    3.0  ye possibl get definit work content pretti int...
# 4                    1.0  professor looney great knowledg astronomi expl...
# ...                  ...                                                ...
# 18974                5.0                      great sens humor love parasit
# 18975                4.0  realli nice guy realli funnyhowev bio 102 not ...
# 18976                3.0  parasitolog class lot work make extrem interes...
# 18977                5.0  way much work 1 credit class shegnoski nice he...
# 18978                2.0  extrem easi lab teacher quizz littl difficult ...
#
# [18979 rows x 2 columns]

# %%
df['student_difficult'].unique()
# Out:
# array([3., 2., 1., 4., 5.])

# %%
# Get a 20% sample of the dataframe
new_df = df.sample(frac=0.2, random_state=42)

# Display the sampled dataframe
print(new_df)

# Optional: Save the sampled data to a new CSV file
new_df.to_csv('sampled_student_stars_and_comments.csv', index=False)

print(f"Original dataframe shape: {df.shape}")
print(f"Sampled dataframe shape: {new_df.shape}")
# Out:
#        student_difficult                                           comments
# 15455                3.0  owe great part success grad school lucki chanc...
# 6634                 4.0  teacher thick accent creat languag barier stud...
# 4724                 4.0            teacher help chanc pick professor great
# 16516                3.0  ador irvin great lectur even manag make econom...
# 13697                3.0  love clinic instructor classroom wonder made e...
# ...                  ...                                                ...
# 18635                4.0  soo freak stupid laugh made cring nobodi come ...
# 6119                 5.0  she prof actress teach act hello peopleif aren...
# 5148                 3.0  open book open note still not east wrote book ...
# 5377                 4.0  dr damen amazingli help far one favorit profes...
# 12564                4.0  took class freshman year super challeng realli...
#
# [3796 rows x 2 columns]
# Original dataframe shape: (18979, 2)
# Sampled dataframe shape: (3796, 2)

# %%
# Defining some key variables that will be used later on in the training
MAX_LEN = 150
TRAIN_BATCH_SIZE = 8
VALID_BATCH_SIZE = 4
# EPOCHS = 1
LEARNING_RATE = 1e-05
tokenizer = RobertaTokenizer.from_pretrained('roberta-base', truncation=True, do_lower_case=True)

# %%
class SentimentData(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.text = dataframe.comments
        self.targets = self.data.student_difficult
        self.max_len = max_len

    def __len__(self):
        return len(self.text)

    def __getitem__(self, index):
        text = str(self.text[index])
        text = " ".join(text.split())

        inputs = self.tokenizer.encode_plus(
            text,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            pad_to_max_length=True,
            return_token_type_ids=True
        )
        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        token_type_ids = inputs["token_type_ids"]


        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.long),
            'token_type_ids': torch.tensor(token_type_ids, dtype=torch.long),
            'targets': torch.tensor(self.targets[index], dtype=torch.float)
        }

# %%
train_size = 0.8
train_data=new_df.sample(frac=train_size,random_state=200)
test_data=new_df.drop(train_data.index).reset_index(drop=True)
train_data = train_data.reset_index(drop=True)


print("FULL Dataset: {}".format(new_df.shape))
print("TRAIN Dataset: {}".format(train_data.shape))
print("TEST Dataset: {}".format(test_data.shape))

training_set = SentimentData(train_data, tokenizer, MAX_LEN)
testing_set = SentimentData(test_data, tokenizer, MAX_LEN)
# Out:
# FULL Dataset: (3796, 2)
# TRAIN Dataset: (3037, 2)
# TEST Dataset: (759, 2)

# %%
train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

training_loader = DataLoader(training_set, **train_params)
testing_loader = DataLoader(testing_set, **test_params)

# %%
class RobertaClass(torch.nn.Module):
    def __init__(self):
        super(RobertaClass, self).__init__()
        self.l1 = RobertaModel.from_pretrained("roberta-base")
        self.pre_classifier = torch.nn.Linear(768, 768)
        self.dropout = torch.nn.Dropout(0.3)
        self.classifier = torch.nn.Linear(768, 5)
        # self.regressor = torch.nn.Linear(768, 1)

    def forward(self, input_ids, attention_mask, token_type_ids):
        output_1 = self.l1(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
        hidden_state = output_1[0]
        pooler = hidden_state[:, 0]
        pooler = self.pre_classifier(pooler)
        pooler = torch.nn.ReLU()(pooler)
        pooler = self.dropout(pooler)
        output = self.classifier(pooler)
        return output

# %%
model = RobertaClass()
model.to(device)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# RobertaClass(
#   (l1): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (classifier): Linear(in_features=768, out_features=5, bias=True)
# )

# %%
# Creating the loss function and optimizer
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params =  model.parameters(), lr=LEARNING_RATE)

# %%
def calcuate_accuracy(preds, targets):
    n_correct = (preds==targets).sum().item()
    return n_correct

# %%
# Defining the training function on the 80% of the dataset for tuning the distilbert model

def train(epoch):
    tr_loss = 0
    n_correct = 0
    nb_tr_steps = 0
    nb_tr_examples = 0
    model.train()
    for _,data in tqdm(enumerate(training_loader, 0)):
        ids = data['ids'].to(device, dtype = torch.long)
        mask = data['mask'].to(device, dtype = torch.long)
        token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
        targets = data['targets'].to(device, dtype = torch.long)

        outputs = model(ids, mask, token_type_ids)
        # print(f"outputs: {outputs}")
        # print(f"targets: {targets}")
        adjusted_targets = targets - 1
        loss = loss_function(outputs, adjusted_targets)
        tr_loss += loss.item()
        big_val, big_idx = torch.max(outputs.data, dim=1)
        n_correct += calcuate_accuracy(big_idx, targets)

        nb_tr_steps += 1
        nb_tr_examples+=targets.size(0)
        
        if _%500==0:
            loss_step = tr_loss/nb_tr_steps
            accu_step = (n_correct*100)/nb_tr_examples 
            print(f"Training Loss per 500 steps: {loss_step}")
            print(f"Training Accuracy per 500 steps: {accu_step}")

        optimizer.zero_grad()
        loss.backward()
        # # When using GPU
        optimizer.step()

    print(f'The Total Accuracy for Epoch {epoch}: {(n_correct*100)/nb_tr_examples}')
    epoch_loss = tr_loss/nb_tr_steps
    epoch_accu = (n_correct*100)/nb_tr_examples
    print(f"Training Loss Epoch: {epoch_loss}")
    print(f"Training Accuracy Epoch: {epoch_accu}")

    return

# %%
EPOCHS = 5
for epoch in range(EPOCHS):
    train(epoch)
# Out:
# 0it [00:00, ?it/s]
# Training Loss per 50 steps: 1.6189857721328735
# Training Accuracy per 50 steps: 12.5
# 19it [03:18, 10.43s/it]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=52bd1650-3b0b-4b86-9c83-4404b785a260' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
